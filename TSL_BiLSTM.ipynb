# %% [markdown]
# # Import initial libraries

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import mediapipe as mp
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense, Bidirectional, Dropout
from sklearn.metrics import multilabel_confusion_matrix
from keras.optimizers import Adamax, Adagrad, RMSprop, Adam

# %% [markdown]
# # Create MediaPipe Function for Detect Body

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)) 
    
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)) 
    
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)) 
    
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2))

# %% [markdown]
# # Test MediaPipe Function with real camera

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
#         print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# # Create Extract Function for Extract Feature

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %% [markdown]
# # Create Datasets

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('DATASET') 

# Actions that we try to detect
actions = np.array(['Beautiful', 'Clever', 'Cute', 'Dislike', 'Fine',
                    'Full', 'Good Luck', 'Hungry', 'Intelligent', 'Like',
                    'Love', 'Regret', 'Sad', 'Sick','Sorry',
                    'Thank You', "That's OK", 'Think of', 'Understand',])

# actions = np.array(['Like', 'Love', 'None'])
# Thirty videos worth of data
no_sequences = 90

# Videos are going to be 30 frames in length
sequence_length = 30

# %% [markdown]
# # Prepare Data for train and test

# %%
label_map = {label:num for num, label in enumerate(actions)}
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
X = np.array(sequences)
y = to_categorical(labels).astype(int)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

# %%
X_train.shape

# %% [markdown]
# # Train model

# %% [markdown]
# Train BiLSTM Model

# %%
# lr = 0.1 # learning rate value
optimizer = Adamax()

model_BiLSTM = Sequential([
    Bidirectional(LSTM(128, return_sequences=True,
                  activation='relu', input_shape=(30, 1662))),
    Dropout(0.1),
    Bidirectional(LSTM(256, return_sequences=True, activation='relu')),
    Dropout(0.1),
    Bidirectional(LSTM(128, return_sequences=False, activation='relu')),
    Dropout(0.1),
    Dense(64, activation='relu'),
    Dropout(0.1),
    Dense(32, activation='relu'),
    Dense(actions.shape[0], activation='softmax')])

model_BiLSTM.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=[
                     'categorical_accuracy'])
model_BiLSTM.fit(X_train, y_train, validation_data=(
    X_test, y_test), epochs=590)
# Out:
# Epoch 1/590
# 1/1 [==============================] - 22s 22s/step - loss: 2.9588 - categorical_accuracy: 0.0614 - val_loss: 3.0229 - val_categorical_accuracy: 0.0541
# Epoch 2/590
# 1/1 [==============================] - 11s 11s/step - loss: 3.0384 - categorical_accuracy: 0.0614 - val_loss: 2.9427 - val_categorical_accuracy: 0.0599
# Epoch 3/590
# 1/1 [==============================] - 11s 11s/step - loss: 2.9503 - categorical_accuracy: 0.0468 - val_loss: 2.9525 - val_categorical_accuracy: 0.1023
# Epoch 4/590
# 1/1 [==============================] - 12s 12s/step - loss: 3.0164 - categorical_accuracy: 0.0604 - val_loss: 2.8937 - val_categorical_accuracy: 0.0892
# Epoch 5/590
# 1/1 [==============================] - 11s 11s/step - loss: 2.9466 - categorical_accuracy: 0.0526 - val_loss: 2.8681 - val_categorical_accuracy: 0.0921
# Epoch 6/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.8874 - categorical_accuracy: 0.0721 - val_loss: 3.7759 - val_categorical_accuracy: 0.0541
# Epoch 7/590
# 1/1 [==============================] - 10s 10s/step - loss: 3.6990 - categorical_accuracy: 0.0556 - val_loss: 2.8010 - val_categorical_accuracy: 0.0994
# Epoch 8/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.8274 - categorical_accuracy: 0.0858 - val_loss: 2.8460 - val_categorical_accuracy: 0.0994
# Epoch 9/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.8699 - categorical_accuracy: 0.0789 - val_loss: 2.7815 - val_categorical_accuracy: 0.0512
# Epoch 10/590
# 1/1 [==============================] - 11s 11s/step - loss: 2.8109 - categorical_accuracy: 0.0731 - val_loss: 3.1102 - val_categorical_accuracy: 0.0526
# Epoch 11/590
# 1/1 [==============================] - 11s 11s/step - loss: 3.3110 - categorical_accuracy: 0.0643 - val_loss: 2.7598 - val_categorical_accuracy: 0.0980
# Epoch 12/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.8002 - categorical_accuracy: 0.1053 - val_loss: 2.8450 - val_categorical_accuracy: 0.0980
# Epoch 13/590
# 1/1 [==============================] - 11s 11s/step - loss: 2.8691 - categorical_accuracy: 0.1131 - val_loss: 2.8519 - val_categorical_accuracy: 0.0994
# Epoch 14/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.8689 - categorical_accuracy: 0.1023 - val_loss: 2.8245 - val_categorical_accuracy: 0.1009
# Epoch 15/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.8485 - categorical_accuracy: 0.0906 - val_loss: 2.7925 - val_categorical_accuracy: 0.0804
# Epoch 16/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.8170 - categorical_accuracy: 0.0877 - val_loss: 2.8119 - val_categorical_accuracy: 0.0673
# Epoch 17/590
# 1/1 [==============================] - 11s 11s/step - loss: 2.8341 - categorical_accuracy: 0.0702 - val_loss: 2.7617 - val_categorical_accuracy: 0.1023
# Epoch 18/590
# 1/1 [==============================] - 11s 11s/step - loss: 2.7961 - categorical_accuracy: 0.0955 - val_loss: 2.7302 - val_categorical_accuracy: 0.0848
# Epoch 19/590
# 1/1 [==============================] - 11s 11s/step - loss: 2.7615 - categorical_accuracy: 0.1150 - val_loss: 2.7300 - val_categorical_accuracy: 0.0848
# Epoch 20/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.7798 - categorical_accuracy: 0.0906 - val_loss: 2.7105 - val_categorical_accuracy: 0.0848
# Epoch 21/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.7359 - categorical_accuracy: 0.1199 - val_loss: 2.6743 - val_categorical_accuracy: 0.0848
# Epoch 22/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.7079 - categorical_accuracy: 0.1131 - val_loss: 2.6653 - val_categorical_accuracy: 0.0848
# Epoch 23/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.7150 - categorical_accuracy: 0.1199 - val_loss: 2.6469 - val_categorical_accuracy: 0.1111
# Epoch 24/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.7012 - categorical_accuracy: 0.1101 - val_loss: 2.6465 - val_categorical_accuracy: 0.1140
# Epoch 25/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.6689 - categorical_accuracy: 0.1179 - val_loss: 2.6400 - val_categorical_accuracy: 0.1126
# Epoch 26/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.6679 - categorical_accuracy: 0.1179 - val_loss: 2.6207 - val_categorical_accuracy: 0.1126
# Epoch 27/590
# 1/1 [==============================] - 11s 11s/step - loss: 2.6555 - categorical_accuracy: 0.1072 - val_loss: 2.6115 - val_categorical_accuracy: 0.1213
# Epoch 28/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.6407 - categorical_accuracy: 0.1218 - val_loss: 2.5937 - val_categorical_accuracy: 0.1170
# Epoch 29/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.6307 - categorical_accuracy: 0.1248 - val_loss: 2.5812 - val_categorical_accuracy: 0.1520
# Epoch 30/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.6180 - categorical_accuracy: 0.1179 - val_loss: 2.5647 - val_categorical_accuracy: 0.1637
# Epoch 31/590
# 1/1 [==============================] - 9s 9s/step - loss: 2.6000 - categorical_accuracy: 0.1179 - val_loss: 2.5333 - val_categorical_accuracy: 0.1170
# Epoch 32/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.5997 - categorical_accuracy: 0.1238 - val_loss: 2.5205 - val_categorical_accuracy: 0.1330
# Epoch 33/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.5837 - categorical_accuracy: 0.1189 - val_loss: 2.5068 - val_categorical_accuracy: 0.1491
# Epoch 34/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.5513 - categorical_accuracy: 0.1501 - val_loss: 2.4682 - val_categorical_accuracy: 0.1550
# Epoch 35/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.5318 - categorical_accuracy: 0.1511 - val_loss: 2.4057 - val_categorical_accuracy: 0.2135
# Epoch 36/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.5189 - categorical_accuracy: 0.1559 - val_loss: 2.4682 - val_categorical_accuracy: 0.2120
# Epoch 37/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.5609 - categorical_accuracy: 0.1559 - val_loss: 2.4568 - val_categorical_accuracy: 0.1213
# Epoch 38/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.5836 - categorical_accuracy: 0.1238 - val_loss: 2.4383 - val_categorical_accuracy: 0.1798
# Epoch 39/590
# 1/1 [==============================] - 9s 9s/step - loss: 2.5405 - categorical_accuracy: 0.1754 - val_loss: 2.4256 - val_categorical_accuracy: 0.1988
# Epoch 40/590
# 1/1 [==============================] - 9s 9s/step - loss: 2.5117 - categorical_accuracy: 0.1901 - val_loss: 2.4408 - val_categorical_accuracy: 0.1769
# Epoch 41/590
# 1/1 [==============================] - 9s 9s/step - loss: 2.4909 - categorical_accuracy: 0.1667 - val_loss: 2.4961 - val_categorical_accuracy: 0.1871
# Epoch 42/590
# 1/1 [==============================] - 9s 9s/step - loss: 2.5245 - categorical_accuracy: 0.1706 - val_loss: 2.4450 - val_categorical_accuracy: 0.2412
# Epoch 43/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.4835 - categorical_accuracy: 0.1774 - val_loss: 2.3448 - val_categorical_accuracy: 0.2164
# Epoch 44/590
# 1/1 [==============================] - 9s 9s/step - loss: 2.4555 - categorical_accuracy: 0.1832 - val_loss: 2.3044 - val_categorical_accuracy: 0.2339
# Epoch 45/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.4644 - categorical_accuracy: 0.1901 - val_loss: 2.4043 - val_categorical_accuracy: 0.2266
# Epoch 46/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.5182 - categorical_accuracy: 0.1813 - val_loss: 2.2824 - val_categorical_accuracy: 0.2368
# Epoch 47/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.3853 - categorical_accuracy: 0.1979 - val_loss: 2.3132 - val_categorical_accuracy: 0.2105
# Epoch 48/590
# 1/1 [==============================] - 9s 9s/step - loss: 2.4500 - categorical_accuracy: 0.2086 - val_loss: 2.2977 - val_categorical_accuracy: 0.2412
# Epoch 49/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.4261 - categorical_accuracy: 0.2037 - val_loss: 2.3217 - val_categorical_accuracy: 0.2368
# Epoch 50/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.3968 - categorical_accuracy: 0.2232 - val_loss: 2.3162 - val_categorical_accuracy: 0.2529
# Epoch 51/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.4030 - categorical_accuracy: 0.2047 - val_loss: 2.2596 - val_categorical_accuracy: 0.2778
# Epoch 52/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.3533 - categorical_accuracy: 0.2183 - val_loss: 2.2285 - val_categorical_accuracy: 0.2398
# Epoch 53/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.3935 - categorical_accuracy: 0.2164 - val_loss: 2.2201 - val_categorical_accuracy: 0.2734
# Epoch 54/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.2995 - categorical_accuracy: 0.2203 - val_loss: 2.1973 - val_categorical_accuracy: 0.2456
# Epoch 55/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.3272 - categorical_accuracy: 0.1930 - val_loss: 2.1403 - val_categorical_accuracy: 0.2749
# Epoch 56/590
# 1/1 [==============================] - 11s 11s/step - loss: 2.3234 - categorical_accuracy: 0.2242 - val_loss: 2.1564 - val_categorical_accuracy: 0.2354
# Epoch 57/590
# 1/1 [==============================] - 11s 11s/step - loss: 2.2984 - categorical_accuracy: 0.1979 - val_loss: 2.0793 - val_categorical_accuracy: 0.2953
# Epoch 58/590
# 1/1 [==============================] - 11s 11s/step - loss: 2.2448 - categorical_accuracy: 0.2290 - val_loss: 2.1078 - val_categorical_accuracy: 0.2675
# Epoch 59/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.2697 - categorical_accuracy: 0.2300 - val_loss: 2.0591 - val_categorical_accuracy: 0.3450
# Epoch 60/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.2144 - categorical_accuracy: 0.2359 - val_loss: 2.1072 - val_categorical_accuracy: 0.3333
# Epoch 61/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.2249 - categorical_accuracy: 0.2388 - val_loss: 2.0031 - val_categorical_accuracy: 0.3289
# Epoch 62/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.1800 - categorical_accuracy: 0.2466 - val_loss: 1.9931 - val_categorical_accuracy: 0.3129
# Epoch 63/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.2133 - categorical_accuracy: 0.2222 - val_loss: 1.9752 - val_categorical_accuracy: 0.3275
# Epoch 64/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.1333 - categorical_accuracy: 0.2602 - val_loss: 1.9302 - val_categorical_accuracy: 0.3436
# Epoch 65/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.1290 - categorical_accuracy: 0.2651 - val_loss: 1.9893 - val_categorical_accuracy: 0.2939
# Epoch 66/590
# 1/1 [==============================] - 9s 9s/step - loss: 2.2121 - categorical_accuracy: 0.2524 - val_loss: 1.9903 - val_categorical_accuracy: 0.3450
# Epoch 67/590
# 1/1 [==============================] - 9s 9s/step - loss: 2.1301 - categorical_accuracy: 0.2583 - val_loss: 2.0279 - val_categorical_accuracy: 0.3436
# Epoch 68/590
# 1/1 [==============================] - 9s 9s/step - loss: 2.1735 - categorical_accuracy: 0.2271 - val_loss: 1.9014 - val_categorical_accuracy: 0.3596
# Epoch 69/590
# 1/1 [==============================] - 9s 9s/step - loss: 2.0716 - categorical_accuracy: 0.2729 - val_loss: 1.9258 - val_categorical_accuracy: 0.3348
# Epoch 70/590
# 1/1 [==============================] - 9s 9s/step - loss: 2.1274 - categorical_accuracy: 0.2797 - val_loss: 1.8512 - val_categorical_accuracy: 0.3743
# Epoch 71/590
# 1/1 [==============================] - 9s 9s/step - loss: 2.0314 - categorical_accuracy: 0.2778 - val_loss: 1.8930 - val_categorical_accuracy: 0.3640
# Epoch 72/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.0594 - categorical_accuracy: 0.2797 - val_loss: 1.8197 - val_categorical_accuracy: 0.3860
# Epoch 73/590
# 1/1 [==============================] - 9s 9s/step - loss: 2.0353 - categorical_accuracy: 0.2973 - val_loss: 1.7681 - val_categorical_accuracy: 0.3772
# Epoch 74/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.9621 - categorical_accuracy: 0.3207 - val_loss: 1.7930 - val_categorical_accuracy: 0.3874
# Epoch 75/590
# 1/1 [==============================] - 9s 9s/step - loss: 1.9471 - categorical_accuracy: 0.3363 - val_loss: 1.7066 - val_categorical_accuracy: 0.4020
# Epoch 76/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.9211 - categorical_accuracy: 0.3363 - val_loss: 1.7320 - val_categorical_accuracy: 0.3874
# Epoch 77/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.9584 - categorical_accuracy: 0.3304 - val_loss: 1.7451 - val_categorical_accuracy: 0.4094
# Epoch 78/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.9645 - categorical_accuracy: 0.3382 - val_loss: 1.6326 - val_categorical_accuracy: 0.4152
# Epoch 79/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.8675 - categorical_accuracy: 0.3411 - val_loss: 1.6394 - val_categorical_accuracy: 0.4284
# Epoch 80/590
# 1/1 [==============================] - 13s 13s/step - loss: 1.9172 - categorical_accuracy: 0.3285 - val_loss: 1.6473 - val_categorical_accuracy: 0.4035
# Epoch 81/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.8449 - categorical_accuracy: 0.3285 - val_loss: 1.6140 - val_categorical_accuracy: 0.4386
# Epoch 82/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.8340 - categorical_accuracy: 0.3538 - val_loss: 1.6258 - val_categorical_accuracy: 0.3991
# Epoch 83/590
# 1/1 [==============================] - 9s 9s/step - loss: 1.8518 - categorical_accuracy: 0.3528 - val_loss: 1.5493 - val_categorical_accuracy: 0.4474
# Epoch 84/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.8322 - categorical_accuracy: 0.3626 - val_loss: 1.5142 - val_categorical_accuracy: 0.4693
# Epoch 85/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.7722 - categorical_accuracy: 0.3938 - val_loss: 1.5933 - val_categorical_accuracy: 0.4094
# Epoch 86/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.8749 - categorical_accuracy: 0.3421 - val_loss: 1.5186 - val_categorical_accuracy: 0.4459
# Epoch 87/590
# 1/1 [==============================] - 9s 9s/step - loss: 1.7802 - categorical_accuracy: 0.3762 - val_loss: 1.4392 - val_categorical_accuracy: 0.4810
# Epoch 88/590
# 1/1 [==============================] - 9s 9s/step - loss: 1.6712 - categorical_accuracy: 0.4025 - val_loss: 1.5286 - val_categorical_accuracy: 0.4225
# Epoch 89/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.7641 - categorical_accuracy: 0.3821 - val_loss: 1.4357 - val_categorical_accuracy: 0.4868
# Epoch 90/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.6880 - categorical_accuracy: 0.4191 - val_loss: 1.4411 - val_categorical_accuracy: 0.5015
# Epoch 91/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.6619 - categorical_accuracy: 0.4269 - val_loss: 1.3817 - val_categorical_accuracy: 0.4883
# Epoch 92/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.6338 - categorical_accuracy: 0.4113 - val_loss: 1.3495 - val_categorical_accuracy: 0.4868
# Epoch 93/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.6273 - categorical_accuracy: 0.4250 - val_loss: 1.3346 - val_categorical_accuracy: 0.4868
# Epoch 94/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.5843 - categorical_accuracy: 0.4240 - val_loss: 1.3181 - val_categorical_accuracy: 0.4912
# Epoch 95/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.5489 - categorical_accuracy: 0.4327 - val_loss: 1.2831 - val_categorical_accuracy: 0.5029
# Epoch 96/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.5287 - categorical_accuracy: 0.4678 - val_loss: 1.2787 - val_categorical_accuracy: 0.5015
# Epoch 97/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.5163 - categorical_accuracy: 0.4581 - val_loss: 1.2422 - val_categorical_accuracy: 0.5000
# Epoch 98/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.4937 - categorical_accuracy: 0.4571 - val_loss: 1.1874 - val_categorical_accuracy: 0.5468
# Epoch 99/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.4580 - categorical_accuracy: 0.4776 - val_loss: 1.3586 - val_categorical_accuracy: 0.4795
# Epoch 100/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.5931 - categorical_accuracy: 0.4318 - val_loss: 1.8501 - val_categorical_accuracy: 0.3874
# Epoch 101/590
# 1/1 [==============================] - 10s 10s/step - loss: 2.1605 - categorical_accuracy: 0.3441 - val_loss: 1.5435 - val_categorical_accuracy: 0.4620
# Epoch 102/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.7900 - categorical_accuracy: 0.3899 - val_loss: 1.6769 - val_categorical_accuracy: 0.4094
# Epoch 103/590
# 1/1 [==============================] - 9s 9s/step - loss: 1.9473 - categorical_accuracy: 0.3343 - val_loss: 1.7061 - val_categorical_accuracy: 0.4108
# Epoch 104/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.9393 - categorical_accuracy: 0.3246 - val_loss: 1.6467 - val_categorical_accuracy: 0.4678
# Epoch 105/590
# 1/1 [==============================] - 9s 9s/step - loss: 1.8703 - categorical_accuracy: 0.3577 - val_loss: 1.7539 - val_categorical_accuracy: 0.4430
# Epoch 106/590
# 1/1 [==============================] - 9s 9s/step - loss: 1.9422 - categorical_accuracy: 0.3616 - val_loss: 1.7253 - val_categorical_accuracy: 0.4342
# Epoch 107/590
# 1/1 [==============================] - 9s 9s/step - loss: 1.8953 - categorical_accuracy: 0.3674 - val_loss: 1.5976 - val_categorical_accuracy: 0.4342
# Epoch 108/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.7741 - categorical_accuracy: 0.3811 - val_loss: 1.6562 - val_categorical_accuracy: 0.3728
# Epoch 109/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.8494 - categorical_accuracy: 0.3431 - val_loss: 1.5842 - val_categorical_accuracy: 0.3904
# Epoch 110/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.7983 - categorical_accuracy: 0.3509 - val_loss: 1.5877 - val_categorical_accuracy: 0.4284
# Epoch 111/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.7687 - categorical_accuracy: 0.3811 - val_loss: 1.5888 - val_categorical_accuracy: 0.4678
# Epoch 112/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.7718 - categorical_accuracy: 0.3567 - val_loss: 1.5135 - val_categorical_accuracy: 0.5117
# Epoch 113/590
# 1/1 [==============================] - 12s 12s/step - loss: 1.6836 - categorical_accuracy: 0.3899 - val_loss: 1.5355 - val_categorical_accuracy: 0.3991
# Epoch 114/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.7033 - categorical_accuracy: 0.3772 - val_loss: 1.4580 - val_categorical_accuracy: 0.4240
# Epoch 115/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.6546 - categorical_accuracy: 0.3713 - val_loss: 1.4307 - val_categorical_accuracy: 0.5058
# Epoch 116/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.6150 - categorical_accuracy: 0.4201 - val_loss: 1.4268 - val_categorical_accuracy: 0.4942
# Epoch 117/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.6593 - categorical_accuracy: 0.3811 - val_loss: 1.3667 - val_categorical_accuracy: 0.4810
# Epoch 118/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.5708 - categorical_accuracy: 0.4142 - val_loss: 1.3389 - val_categorical_accuracy: 0.4912
# Epoch 119/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.5567 - categorical_accuracy: 0.4152 - val_loss: 1.3184 - val_categorical_accuracy: 0.4868
# Epoch 120/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.5383 - categorical_accuracy: 0.4357 - val_loss: 1.3004 - val_categorical_accuracy: 0.5102
# Epoch 121/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.5085 - categorical_accuracy: 0.4483 - val_loss: 1.2713 - val_categorical_accuracy: 0.5219
# Epoch 122/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.4789 - categorical_accuracy: 0.4708 - val_loss: 1.2216 - val_categorical_accuracy: 0.5058
# Epoch 123/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.4546 - categorical_accuracy: 0.4815 - val_loss: 1.2013 - val_categorical_accuracy: 0.5219
# Epoch 124/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.4383 - categorical_accuracy: 0.4698 - val_loss: 1.1681 - val_categorical_accuracy: 0.5292
# Epoch 125/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.4382 - categorical_accuracy: 0.4669 - val_loss: 1.1598 - val_categorical_accuracy: 0.5205
# Epoch 126/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.3824 - categorical_accuracy: 0.4766 - val_loss: 1.2124 - val_categorical_accuracy: 0.4985
# Epoch 127/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.4393 - categorical_accuracy: 0.4659 - val_loss: 1.1326 - val_categorical_accuracy: 0.5673
# Epoch 128/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.3967 - categorical_accuracy: 0.4854 - val_loss: 1.0931 - val_categorical_accuracy: 0.6038
# Epoch 129/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.3646 - categorical_accuracy: 0.5010 - val_loss: 1.1166 - val_categorical_accuracy: 0.5307
# Epoch 130/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.4241 - categorical_accuracy: 0.4737 - val_loss: 1.0405 - val_categorical_accuracy: 0.6096
# Epoch 131/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.3277 - categorical_accuracy: 0.5000 - val_loss: 1.0566 - val_categorical_accuracy: 0.6360
# Epoch 132/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.3625 - categorical_accuracy: 0.5156 - val_loss: 1.0854 - val_categorical_accuracy: 0.5497
# Epoch 133/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.3227 - categorical_accuracy: 0.5234 - val_loss: 1.0760 - val_categorical_accuracy: 0.5892
# Epoch 134/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.2388 - categorical_accuracy: 0.5156 - val_loss: 1.0303 - val_categorical_accuracy: 0.6345
# Epoch 135/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.2530 - categorical_accuracy: 0.5244 - val_loss: 0.9966 - val_categorical_accuracy: 0.6477
# Epoch 136/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.2183 - categorical_accuracy: 0.5536 - val_loss: 1.1569 - val_categorical_accuracy: 0.5409
# Epoch 137/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.3376 - categorical_accuracy: 0.5224 - val_loss: 1.0097 - val_categorical_accuracy: 0.6155
# Epoch 138/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.2491 - categorical_accuracy: 0.5273 - val_loss: 1.0525 - val_categorical_accuracy: 0.6506
# Epoch 139/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.2823 - categorical_accuracy: 0.5478 - val_loss: 1.0332 - val_categorical_accuracy: 0.6272
# Epoch 140/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.2266 - categorical_accuracy: 0.5575 - val_loss: 1.0656 - val_categorical_accuracy: 0.6213
# Epoch 141/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.2427 - categorical_accuracy: 0.5419 - val_loss: 1.0242 - val_categorical_accuracy: 0.6096
# Epoch 142/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.1983 - categorical_accuracy: 0.5439 - val_loss: 0.9368 - val_categorical_accuracy: 0.6447
# Epoch 143/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.1286 - categorical_accuracy: 0.5604 - val_loss: 0.9380 - val_categorical_accuracy: 0.6667
# Epoch 144/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.1735 - categorical_accuracy: 0.5595 - val_loss: 1.0025 - val_categorical_accuracy: 0.6096
# Epoch 145/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.2701 - categorical_accuracy: 0.5312 - val_loss: 0.8962 - val_categorical_accuracy: 0.6564
# Epoch 146/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.1402 - categorical_accuracy: 0.5526 - val_loss: 0.9858 - val_categorical_accuracy: 0.5819
# Epoch 147/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.2704 - categorical_accuracy: 0.5546 - val_loss: 1.2325 - val_categorical_accuracy: 0.5292
# Epoch 148/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.4019 - categorical_accuracy: 0.4903 - val_loss: 1.1150 - val_categorical_accuracy: 0.5702
# Epoch 149/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.3008 - categorical_accuracy: 0.5244 - val_loss: 1.1442 - val_categorical_accuracy: 0.5117
# Epoch 150/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.3657 - categorical_accuracy: 0.4844 - val_loss: 1.0456 - val_categorical_accuracy: 0.6374
# Epoch 151/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.2612 - categorical_accuracy: 0.5175 - val_loss: 1.0411 - val_categorical_accuracy: 0.6170
# Epoch 152/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.2740 - categorical_accuracy: 0.5565 - val_loss: 0.9497 - val_categorical_accuracy: 0.6550
# Epoch 153/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.0760 - categorical_accuracy: 0.5906 - val_loss: 1.2831 - val_categorical_accuracy: 0.5102
# Epoch 154/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.3850 - categorical_accuracy: 0.5107 - val_loss: 1.0242 - val_categorical_accuracy: 0.6389
# Epoch 155/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.2388 - categorical_accuracy: 0.5565 - val_loss: 0.9599 - val_categorical_accuracy: 0.6696
# Epoch 156/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.1655 - categorical_accuracy: 0.5936 - val_loss: 1.0518 - val_categorical_accuracy: 0.6594
# Epoch 157/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.1875 - categorical_accuracy: 0.5770 - val_loss: 1.0394 - val_categorical_accuracy: 0.6506
# Epoch 158/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.2134 - categorical_accuracy: 0.5468 - val_loss: 0.9372 - val_categorical_accuracy: 0.6974
# Epoch 159/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.0999 - categorical_accuracy: 0.6101 - val_loss: 0.9229 - val_categorical_accuracy: 0.6769
# Epoch 160/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.0797 - categorical_accuracy: 0.6189 - val_loss: 0.9739 - val_categorical_accuracy: 0.6330
# Epoch 161/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.1311 - categorical_accuracy: 0.6043 - val_loss: 0.9020 - val_categorical_accuracy: 0.6886
# Epoch 162/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.1349 - categorical_accuracy: 0.6160 - val_loss: 0.8953 - val_categorical_accuracy: 0.6550
# Epoch 163/590
# 1/1 [==============================] - 11s 11s/step - loss: 1.0595 - categorical_accuracy: 0.5838 - val_loss: 0.7878 - val_categorical_accuracy: 0.7193
# Epoch 164/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.9776 - categorical_accuracy: 0.6287 - val_loss: 0.8373 - val_categorical_accuracy: 0.7018
# Epoch 165/590
# 1/1 [==============================] - 12s 12s/step - loss: 1.1065 - categorical_accuracy: 0.5936 - val_loss: 0.9208 - val_categorical_accuracy: 0.6404
# Epoch 166/590
# 1/1 [==============================] - 13s 13s/step - loss: 1.0652 - categorical_accuracy: 0.6014 - val_loss: 0.7307 - val_categorical_accuracy: 0.7661
# Epoch 167/590
# 1/1 [==============================] - 14s 14s/step - loss: 0.9448 - categorical_accuracy: 0.6481 - val_loss: 0.7084 - val_categorical_accuracy: 0.7719
# Epoch 168/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.9132 - categorical_accuracy: 0.6442 - val_loss: 0.7491 - val_categorical_accuracy: 0.7032
# Epoch 169/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.9155 - categorical_accuracy: 0.6462 - val_loss: 0.6645 - val_categorical_accuracy: 0.7968
# Epoch 170/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.8795 - categorical_accuracy: 0.6598 - val_loss: 0.7437 - val_categorical_accuracy: 0.6901
# Epoch 171/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.9248 - categorical_accuracy: 0.6501 - val_loss: 0.6713 - val_categorical_accuracy: 0.7529
# Epoch 172/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.8728 - categorical_accuracy: 0.6725 - val_loss: 0.6487 - val_categorical_accuracy: 0.7646
# Epoch 173/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.8706 - categorical_accuracy: 0.6784 - val_loss: 0.9640 - val_categorical_accuracy: 0.6213
# Epoch 174/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.0468 - categorical_accuracy: 0.6248 - val_loss: 0.7467 - val_categorical_accuracy: 0.6944
# Epoch 175/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.0703 - categorical_accuracy: 0.6033 - val_loss: 0.7471 - val_categorical_accuracy: 0.7266
# Epoch 176/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.9744 - categorical_accuracy: 0.6335 - val_loss: 0.7449 - val_categorical_accuracy: 0.7222
# Epoch 177/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.9318 - categorical_accuracy: 0.6618 - val_loss: 0.7023 - val_categorical_accuracy: 0.7646
# Epoch 178/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.9158 - categorical_accuracy: 0.6550 - val_loss: 0.7988 - val_categorical_accuracy: 0.6725
# Epoch 179/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.9487 - categorical_accuracy: 0.6589 - val_loss: 0.8357 - val_categorical_accuracy: 0.6608
# Epoch 180/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.9801 - categorical_accuracy: 0.6316 - val_loss: 0.7409 - val_categorical_accuracy: 0.7442
# Epoch 181/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.9883 - categorical_accuracy: 0.6442 - val_loss: 0.7463 - val_categorical_accuracy: 0.7368
# Epoch 182/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.9449 - categorical_accuracy: 0.6394 - val_loss: 0.6356 - val_categorical_accuracy: 0.8070
# Epoch 183/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.8324 - categorical_accuracy: 0.6998 - val_loss: 0.7315 - val_categorical_accuracy: 0.7325
# Epoch 184/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.9079 - categorical_accuracy: 0.6579 - val_loss: 0.8937 - val_categorical_accuracy: 0.6447
# Epoch 185/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.9783 - categorical_accuracy: 0.6374 - val_loss: 0.8104 - val_categorical_accuracy: 0.7105
# Epoch 186/590
# 1/1 [==============================] - 9s 9s/step - loss: 1.0981 - categorical_accuracy: 0.5945 - val_loss: 0.8437 - val_categorical_accuracy: 0.6930
# Epoch 187/590
# 1/1 [==============================] - 9s 9s/step - loss: 1.0060 - categorical_accuracy: 0.6365 - val_loss: 1.0769 - val_categorical_accuracy: 0.5658
# Epoch 188/590
# 1/1 [==============================] - 9s 9s/step - loss: 1.2497 - categorical_accuracy: 0.5361 - val_loss: 0.9212 - val_categorical_accuracy: 0.6316
# Epoch 189/590
# 1/1 [==============================] - 9s 9s/step - loss: 1.0371 - categorical_accuracy: 0.6218 - val_loss: 0.9044 - val_categorical_accuracy: 0.6944
# Epoch 190/590
# 1/1 [==============================] - 9s 9s/step - loss: 1.0668 - categorical_accuracy: 0.6131 - val_loss: 0.7411 - val_categorical_accuracy: 0.7749
# Epoch 191/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.8451 - categorical_accuracy: 0.6910 - val_loss: 1.0119 - val_categorical_accuracy: 0.6243
# Epoch 192/590
# 1/1 [==============================] - 9s 9s/step - loss: 1.1176 - categorical_accuracy: 0.5906 - val_loss: 0.9377 - val_categorical_accuracy: 0.6623
# Epoch 193/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.1144 - categorical_accuracy: 0.5984 - val_loss: 0.8512 - val_categorical_accuracy: 0.6608
# Epoch 194/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.9931 - categorical_accuracy: 0.6335 - val_loss: 0.7642 - val_categorical_accuracy: 0.7456
# Epoch 195/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.8897 - categorical_accuracy: 0.6940 - val_loss: 0.8792 - val_categorical_accuracy: 0.6769
# Epoch 196/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.0870 - categorical_accuracy: 0.6053 - val_loss: 0.6989 - val_categorical_accuracy: 0.7661
# Epoch 197/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.8084 - categorical_accuracy: 0.6959 - val_loss: 0.7930 - val_categorical_accuracy: 0.7310
# Epoch 198/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.8708 - categorical_accuracy: 0.6823 - val_loss: 0.7093 - val_categorical_accuracy: 0.7515
# Epoch 199/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.8474 - categorical_accuracy: 0.6891 - val_loss: 0.6302 - val_categorical_accuracy: 0.7442
# Epoch 200/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.7982 - categorical_accuracy: 0.7096 - val_loss: 0.5874 - val_categorical_accuracy: 0.7924
# Epoch 201/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.7332 - categorical_accuracy: 0.7115 - val_loss: 0.5928 - val_categorical_accuracy: 0.8129
# Epoch 202/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.8183 - categorical_accuracy: 0.7164 - val_loss: 0.7066 - val_categorical_accuracy: 0.7164
# Epoch 203/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.8238 - categorical_accuracy: 0.6920 - val_loss: 0.6936 - val_categorical_accuracy: 0.7193
# Epoch 204/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.9652 - categorical_accuracy: 0.6316 - val_loss: 1.2075 - val_categorical_accuracy: 0.5848
# Epoch 205/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.3178 - categorical_accuracy: 0.5702 - val_loss: 0.5710 - val_categorical_accuracy: 0.7851
# Epoch 206/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.7814 - categorical_accuracy: 0.7057 - val_loss: 0.6714 - val_categorical_accuracy: 0.7208
# Epoch 207/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.9344 - categorical_accuracy: 0.6296 - val_loss: 0.6717 - val_categorical_accuracy: 0.7544
# Epoch 208/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.8937 - categorical_accuracy: 0.6725 - val_loss: 0.7541 - val_categorical_accuracy: 0.6842
# Epoch 209/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.8522 - categorical_accuracy: 0.6813 - val_loss: 0.6507 - val_categorical_accuracy: 0.7734
# Epoch 210/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.7339 - categorical_accuracy: 0.7232 - val_loss: 0.6626 - val_categorical_accuracy: 0.7383
# Epoch 211/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.8116 - categorical_accuracy: 0.6910 - val_loss: 0.6118 - val_categorical_accuracy: 0.7588
# Epoch 212/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.7100 - categorical_accuracy: 0.7320 - val_loss: 0.7063 - val_categorical_accuracy: 0.6754
# Epoch 213/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.8511 - categorical_accuracy: 0.6589 - val_loss: 0.5674 - val_categorical_accuracy: 0.8202
# Epoch 214/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.7610 - categorical_accuracy: 0.7232 - val_loss: 0.5166 - val_categorical_accuracy: 0.8041
# Epoch 215/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.6733 - categorical_accuracy: 0.7437 - val_loss: 0.5315 - val_categorical_accuracy: 0.8070
# Epoch 216/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.7065 - categorical_accuracy: 0.7320 - val_loss: 0.6522 - val_categorical_accuracy: 0.7222
# Epoch 217/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.7688 - categorical_accuracy: 0.7144 - val_loss: 0.5337 - val_categorical_accuracy: 0.8319
# Epoch 218/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.6849 - categorical_accuracy: 0.7593 - val_loss: 0.6039 - val_categorical_accuracy: 0.7778
# Epoch 219/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.7887 - categorical_accuracy: 0.7047 - val_loss: 0.5355 - val_categorical_accuracy: 0.8216
# Epoch 220/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.6569 - categorical_accuracy: 0.7612 - val_loss: 0.5216 - val_categorical_accuracy: 0.8070
# Epoch 221/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.6279 - categorical_accuracy: 0.7661 - val_loss: 0.5457 - val_categorical_accuracy: 0.7646
# Epoch 222/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.6400 - categorical_accuracy: 0.7515 - val_loss: 0.4767 - val_categorical_accuracy: 0.8216
# Epoch 223/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.6605 - categorical_accuracy: 0.7368 - val_loss: 0.4502 - val_categorical_accuracy: 0.8275
# Epoch 224/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.5864 - categorical_accuracy: 0.7885 - val_loss: 0.4814 - val_categorical_accuracy: 0.8216
# Epoch 225/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.6090 - categorical_accuracy: 0.7700 - val_loss: 0.4431 - val_categorical_accuracy: 0.8480
# Epoch 226/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.5568 - categorical_accuracy: 0.7904 - val_loss: 0.4584 - val_categorical_accuracy: 0.8538
# Epoch 227/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.5910 - categorical_accuracy: 0.7602 - val_loss: 0.5443 - val_categorical_accuracy: 0.7734
# Epoch 228/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.5928 - categorical_accuracy: 0.7710 - val_loss: 0.4190 - val_categorical_accuracy: 0.8787
# Epoch 229/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.5238 - categorical_accuracy: 0.8051 - val_loss: 0.3968 - val_categorical_accuracy: 0.8904
# Epoch 230/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.5097 - categorical_accuracy: 0.8207 - val_loss: 0.4010 - val_categorical_accuracy: 0.8655
# Epoch 231/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.4930 - categorical_accuracy: 0.8304 - val_loss: 0.3695 - val_categorical_accuracy: 0.8772
# Epoch 232/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.4615 - categorical_accuracy: 0.8275 - val_loss: 0.3702 - val_categorical_accuracy: 0.8655
# Epoch 233/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.5097 - categorical_accuracy: 0.8080 - val_loss: 0.4203 - val_categorical_accuracy: 0.8319
# Epoch 234/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.5235 - categorical_accuracy: 0.8051 - val_loss: 0.4688 - val_categorical_accuracy: 0.8085
# Epoch 235/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.6891 - categorical_accuracy: 0.7359 - val_loss: 0.4397 - val_categorical_accuracy: 0.8333
# Epoch 236/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.5821 - categorical_accuracy: 0.7904 - val_loss: 0.4523 - val_categorical_accuracy: 0.8231
# Epoch 237/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.5437 - categorical_accuracy: 0.7934 - val_loss: 0.4273 - val_categorical_accuracy: 0.8319
# Epoch 238/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.6182 - categorical_accuracy: 0.7554 - val_loss: 0.4371 - val_categorical_accuracy: 0.8202
# Epoch 239/590
# 1/1 [==============================] - 12s 12s/step - loss: 0.5218 - categorical_accuracy: 0.8080 - val_loss: 0.3505 - val_categorical_accuracy: 0.8918
# Epoch 240/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.4422 - categorical_accuracy: 0.8392 - val_loss: 0.4357 - val_categorical_accuracy: 0.8231
# Epoch 241/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.5629 - categorical_accuracy: 0.7924 - val_loss: 0.3982 - val_categorical_accuracy: 0.8450
# Epoch 242/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.4948 - categorical_accuracy: 0.8070 - val_loss: 0.3747 - val_categorical_accuracy: 0.8787
# Epoch 243/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.4332 - categorical_accuracy: 0.8343 - val_loss: 0.3627 - val_categorical_accuracy: 0.8787
# Epoch 244/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.4799 - categorical_accuracy: 0.8119 - val_loss: 0.3415 - val_categorical_accuracy: 0.9035
# Epoch 245/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.4350 - categorical_accuracy: 0.8402 - val_loss: 0.3385 - val_categorical_accuracy: 0.8991
# Epoch 246/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.4346 - categorical_accuracy: 0.8392 - val_loss: 0.3134 - val_categorical_accuracy: 0.9123
# Epoch 247/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.4040 - categorical_accuracy: 0.8587 - val_loss: 0.3240 - val_categorical_accuracy: 0.9167
# Epoch 248/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.3935 - categorical_accuracy: 0.8684 - val_loss: 0.2988 - val_categorical_accuracy: 0.9327
# Epoch 249/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.3597 - categorical_accuracy: 0.8665 - val_loss: 0.3297 - val_categorical_accuracy: 0.8918
# Epoch 250/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.5394 - categorical_accuracy: 0.8148 - val_loss: 0.7991 - val_categorical_accuracy: 0.7135
# Epoch 251/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.9146 - categorical_accuracy: 0.7105 - val_loss: 0.8330 - val_categorical_accuracy: 0.6959
# Epoch 252/590
# 1/1 [==============================] - 10s 10s/step - loss: 1.1276 - categorical_accuracy: 0.6072 - val_loss: 0.4319 - val_categorical_accuracy: 0.8494
# Epoch 253/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.5746 - categorical_accuracy: 0.7924 - val_loss: 0.7545 - val_categorical_accuracy: 0.7178
# Epoch 254/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.8042 - categorical_accuracy: 0.7183 - val_loss: 0.4023 - val_categorical_accuracy: 0.9020
# Epoch 255/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.4767 - categorical_accuracy: 0.8372 - val_loss: 0.4562 - val_categorical_accuracy: 0.8596
# Epoch 256/590
# 1/1 [==============================] - 14s 14s/step - loss: 0.5985 - categorical_accuracy: 0.7758 - val_loss: 0.4936 - val_categorical_accuracy: 0.8626
# Epoch 257/590
# 1/1 [==============================] - 12s 12s/step - loss: 0.6717 - categorical_accuracy: 0.7446 - val_loss: 0.4603 - val_categorical_accuracy: 0.8787
# Epoch 258/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.5770 - categorical_accuracy: 0.8090 - val_loss: 0.4908 - val_categorical_accuracy: 0.8523
# Epoch 259/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.5958 - categorical_accuracy: 0.7914 - val_loss: 0.4575 - val_categorical_accuracy: 0.8494
# Epoch 260/590
# 1/1 [==============================] - 12s 12s/step - loss: 0.5338 - categorical_accuracy: 0.8207 - val_loss: 0.4011 - val_categorical_accuracy: 0.8699
# Epoch 261/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.5014 - categorical_accuracy: 0.8314 - val_loss: 0.4084 - val_categorical_accuracy: 0.8728
# Epoch 262/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.5240 - categorical_accuracy: 0.8177 - val_loss: 0.3459 - val_categorical_accuracy: 0.9108
# Epoch 263/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.4132 - categorical_accuracy: 0.8704 - val_loss: 0.3362 - val_categorical_accuracy: 0.9006
# Epoch 264/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.4240 - categorical_accuracy: 0.8626 - val_loss: 0.2902 - val_categorical_accuracy: 0.9181
# Epoch 265/590
# 1/1 [==============================] - 8s 8s/step - loss: 0.3793 - categorical_accuracy: 0.8645 - val_loss: 0.2662 - val_categorical_accuracy: 0.9284
# Epoch 266/590
# 1/1 [==============================] - 8s 8s/step - loss: 0.3830 - categorical_accuracy: 0.8743 - val_loss: 0.2552 - val_categorical_accuracy: 0.9415
# Epoch 267/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.3537 - categorical_accuracy: 0.8811 - val_loss: 0.2935 - val_categorical_accuracy: 0.9167
# Epoch 268/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.3761 - categorical_accuracy: 0.8665 - val_loss: 0.2586 - val_categorical_accuracy: 0.9386
# Epoch 269/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.3251 - categorical_accuracy: 0.8860 - val_loss: 0.2333 - val_categorical_accuracy: 0.9415
# Epoch 270/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.3343 - categorical_accuracy: 0.8840 - val_loss: 0.3096 - val_categorical_accuracy: 0.9064
# Epoch 271/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.3920 - categorical_accuracy: 0.8626 - val_loss: 0.2630 - val_categorical_accuracy: 0.9240
# Epoch 272/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.3297 - categorical_accuracy: 0.8830 - val_loss: 0.2752 - val_categorical_accuracy: 0.9167
# Epoch 273/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.3299 - categorical_accuracy: 0.8928 - val_loss: 0.2997 - val_categorical_accuracy: 0.8947
# Epoch 274/590
# 1/1 [==============================] - 8s 8s/step - loss: 0.3031 - categorical_accuracy: 0.8918 - val_loss: 0.2308 - val_categorical_accuracy: 0.9415
# Epoch 275/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.3564 - categorical_accuracy: 0.8694 - val_loss: 0.3286 - val_categorical_accuracy: 0.9152
# Epoch 276/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.3525 - categorical_accuracy: 0.8723 - val_loss: 0.2064 - val_categorical_accuracy: 0.9459
# Epoch 277/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.2739 - categorical_accuracy: 0.9123 - val_loss: 0.2357 - val_categorical_accuracy: 0.9254
# Epoch 278/590
# 1/1 [==============================] - 8s 8s/step - loss: 0.3435 - categorical_accuracy: 0.8733 - val_loss: 0.1808 - val_categorical_accuracy: 0.9561
# Epoch 279/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.2657 - categorical_accuracy: 0.9113 - val_loss: 0.2342 - val_categorical_accuracy: 0.9459
# Epoch 280/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.3292 - categorical_accuracy: 0.8957 - val_loss: 0.2179 - val_categorical_accuracy: 0.9605
# Epoch 281/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.2567 - categorical_accuracy: 0.9113 - val_loss: 0.2377 - val_categorical_accuracy: 0.9547
# Epoch 282/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.2881 - categorical_accuracy: 0.9035 - val_loss: 0.2258 - val_categorical_accuracy: 0.9547
# Epoch 283/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.2751 - categorical_accuracy: 0.9084 - val_loss: 0.2259 - val_categorical_accuracy: 0.9488
# Epoch 284/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.2512 - categorical_accuracy: 0.9103 - val_loss: 0.2357 - val_categorical_accuracy: 0.9444
# Epoch 285/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.2631 - categorical_accuracy: 0.9152 - val_loss: 0.1859 - val_categorical_accuracy: 0.9620
# Epoch 286/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.2358 - categorical_accuracy: 0.9211 - val_loss: 0.1858 - val_categorical_accuracy: 0.9576
# Epoch 287/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.2536 - categorical_accuracy: 0.9045 - val_loss: 0.2046 - val_categorical_accuracy: 0.9430
# Epoch 288/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.2164 - categorical_accuracy: 0.9211 - val_loss: 0.2295 - val_categorical_accuracy: 0.9503
# Epoch 289/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.2759 - categorical_accuracy: 0.9113 - val_loss: 0.2098 - val_categorical_accuracy: 0.9503
# Epoch 290/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.3505 - categorical_accuracy: 0.8791 - val_loss: 0.3391 - val_categorical_accuracy: 0.8713
# Epoch 291/590
# ...
# Epoch 495/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0915 - categorical_accuracy: 0.9717 - val_loss: 0.0978 - val_categorical_accuracy: 0.9810
# Epoch 496/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0942 - categorical_accuracy: 0.9708 - val_loss: 0.0956 - val_categorical_accuracy: 0.9825
# Epoch 497/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0951 - categorical_accuracy: 0.9688 - val_loss: 0.0875 - val_categorical_accuracy: 0.9839
# Epoch 498/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0923 - categorical_accuracy: 0.9747 - val_loss: 0.0945 - val_categorical_accuracy: 0.9839
# Epoch 499/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0993 - categorical_accuracy: 0.9678 - val_loss: 0.1095 - val_categorical_accuracy: 0.9810
# Epoch 500/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0764 - categorical_accuracy: 0.9844 - val_loss: 0.1797 - val_categorical_accuracy: 0.9576
# Epoch 501/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.1072 - categorical_accuracy: 0.9620 - val_loss: 0.1353 - val_categorical_accuracy: 0.9781
# Epoch 502/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.1082 - categorical_accuracy: 0.9737 - val_loss: 0.1198 - val_categorical_accuracy: 0.9781
# Epoch 503/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.1235 - categorical_accuracy: 0.9649 - val_loss: 0.0964 - val_categorical_accuracy: 0.9854
# Epoch 504/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0795 - categorical_accuracy: 0.9747 - val_loss: 0.1453 - val_categorical_accuracy: 0.9605
# Epoch 505/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.1313 - categorical_accuracy: 0.9591 - val_loss: 0.0779 - val_categorical_accuracy: 0.9868
# Epoch 506/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0954 - categorical_accuracy: 0.9688 - val_loss: 0.1010 - val_categorical_accuracy: 0.9781
# Epoch 507/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0956 - categorical_accuracy: 0.9708 - val_loss: 0.1364 - val_categorical_accuracy: 0.9751
# Epoch 508/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0599 - categorical_accuracy: 0.9844 - val_loss: 0.2171 - val_categorical_accuracy: 0.9532
# Epoch 509/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.1220 - categorical_accuracy: 0.9620 - val_loss: 0.1264 - val_categorical_accuracy: 0.9795
# Epoch 510/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0716 - categorical_accuracy: 0.9795 - val_loss: 0.1069 - val_categorical_accuracy: 0.9839
# Epoch 511/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0682 - categorical_accuracy: 0.9805 - val_loss: 0.1040 - val_categorical_accuracy: 0.9854
# Epoch 512/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0704 - categorical_accuracy: 0.9776 - val_loss: 0.1116 - val_categorical_accuracy: 0.9854
# Epoch 513/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0711 - categorical_accuracy: 0.9786 - val_loss: 0.1188 - val_categorical_accuracy: 0.9854
# Epoch 514/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0598 - categorical_accuracy: 0.9844 - val_loss: 0.1272 - val_categorical_accuracy: 0.9825
# Epoch 515/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0646 - categorical_accuracy: 0.9786 - val_loss: 0.1344 - val_categorical_accuracy: 0.9795
# Epoch 516/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0564 - categorical_accuracy: 0.9825 - val_loss: 0.1422 - val_categorical_accuracy: 0.9781
# Epoch 517/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0565 - categorical_accuracy: 0.9825 - val_loss: 0.1454 - val_categorical_accuracy: 0.9766
# Epoch 518/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0695 - categorical_accuracy: 0.9795 - val_loss: 0.1127 - val_categorical_accuracy: 0.9868
# Epoch 519/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0595 - categorical_accuracy: 0.9815 - val_loss: 0.0885 - val_categorical_accuracy: 0.9883
# Epoch 520/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0691 - categorical_accuracy: 0.9844 - val_loss: 0.0827 - val_categorical_accuracy: 0.9883
# Epoch 521/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0644 - categorical_accuracy: 0.9786 - val_loss: 0.0914 - val_categorical_accuracy: 0.9868
# Epoch 522/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0705 - categorical_accuracy: 0.9776 - val_loss: 0.1108 - val_categorical_accuracy: 0.9854
# Epoch 523/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0555 - categorical_accuracy: 0.9805 - val_loss: 0.1340 - val_categorical_accuracy: 0.9781
# Epoch 524/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0543 - categorical_accuracy: 0.9854 - val_loss: 0.1424 - val_categorical_accuracy: 0.9766
# Epoch 525/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0546 - categorical_accuracy: 0.9844 - val_loss: 0.1219 - val_categorical_accuracy: 0.9795
# Epoch 526/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0510 - categorical_accuracy: 0.9854 - val_loss: 0.1058 - val_categorical_accuracy: 0.9795
# Epoch 527/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0644 - categorical_accuracy: 0.9844 - val_loss: 0.0926 - val_categorical_accuracy: 0.9839
# Epoch 528/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0531 - categorical_accuracy: 0.9834 - val_loss: 0.0818 - val_categorical_accuracy: 0.9868
# Epoch 529/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0504 - categorical_accuracy: 0.9815 - val_loss: 0.0823 - val_categorical_accuracy: 0.9854
# Epoch 530/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0543 - categorical_accuracy: 0.9854 - val_loss: 0.0837 - val_categorical_accuracy: 0.9868
# Epoch 531/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0331 - categorical_accuracy: 0.9883 - val_loss: 0.1052 - val_categorical_accuracy: 0.9795
# Epoch 532/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0555 - categorical_accuracy: 0.9844 - val_loss: 0.1123 - val_categorical_accuracy: 0.9795
# Epoch 533/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0519 - categorical_accuracy: 0.9844 - val_loss: 0.0966 - val_categorical_accuracy: 0.9854
# Epoch 534/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0580 - categorical_accuracy: 0.9844 - val_loss: 0.0829 - val_categorical_accuracy: 0.9868
# Epoch 535/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0470 - categorical_accuracy: 0.9834 - val_loss: 0.0790 - val_categorical_accuracy: 0.9883
# Epoch 536/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0459 - categorical_accuracy: 0.9864 - val_loss: 0.0820 - val_categorical_accuracy: 0.9883
# Epoch 537/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0661 - categorical_accuracy: 0.9815 - val_loss: 0.0766 - val_categorical_accuracy: 0.9898
# Epoch 538/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0496 - categorical_accuracy: 0.9864 - val_loss: 0.0767 - val_categorical_accuracy: 0.9898
# Epoch 539/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0387 - categorical_accuracy: 0.9834 - val_loss: 0.0851 - val_categorical_accuracy: 0.9868
# Epoch 540/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0471 - categorical_accuracy: 0.9873 - val_loss: 0.1026 - val_categorical_accuracy: 0.9825
# Epoch 541/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0571 - categorical_accuracy: 0.9795 - val_loss: 0.0951 - val_categorical_accuracy: 0.9868
# Epoch 542/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0330 - categorical_accuracy: 0.9922 - val_loss: 0.0924 - val_categorical_accuracy: 0.9868
# Epoch 543/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0374 - categorical_accuracy: 0.9873 - val_loss: 0.0985 - val_categorical_accuracy: 0.9839
# Epoch 544/590
# 1/1 [==============================] - 16s 16s/step - loss: 0.0455 - categorical_accuracy: 0.9844 - val_loss: 0.0948 - val_categorical_accuracy: 0.9868
# Epoch 545/590
# 1/1 [==============================] - 12s 12s/step - loss: 0.0472 - categorical_accuracy: 0.9844 - val_loss: 0.0900 - val_categorical_accuracy: 0.9883
# Epoch 546/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0331 - categorical_accuracy: 0.9883 - val_loss: 0.0972 - val_categorical_accuracy: 0.9868
# Epoch 547/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0347 - categorical_accuracy: 0.9864 - val_loss: 0.0960 - val_categorical_accuracy: 0.9868
# Epoch 548/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0415 - categorical_accuracy: 0.9864 - val_loss: 0.0953 - val_categorical_accuracy: 0.9868
# Epoch 549/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0376 - categorical_accuracy: 0.9844 - val_loss: 0.0911 - val_categorical_accuracy: 0.9854
# Epoch 550/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0552 - categorical_accuracy: 0.9825 - val_loss: 0.1250 - val_categorical_accuracy: 0.9810
# Epoch 551/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0461 - categorical_accuracy: 0.9864 - val_loss: 0.1520 - val_categorical_accuracy: 0.9722
# Epoch 552/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0545 - categorical_accuracy: 0.9795 - val_loss: 0.1093 - val_categorical_accuracy: 0.9854
# Epoch 553/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0424 - categorical_accuracy: 0.9844 - val_loss: 0.0971 - val_categorical_accuracy: 0.9839
# Epoch 554/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0664 - categorical_accuracy: 0.9815 - val_loss: 0.0878 - val_categorical_accuracy: 0.9883
# Epoch 555/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0337 - categorical_accuracy: 0.9893 - val_loss: 0.1171 - val_categorical_accuracy: 0.9766
# Epoch 556/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0756 - categorical_accuracy: 0.9756 - val_loss: 0.0909 - val_categorical_accuracy: 0.9883
# Epoch 557/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0437 - categorical_accuracy: 0.9834 - val_loss: 0.0987 - val_categorical_accuracy: 0.9854
# Epoch 558/590
# 1/1 [==============================] - 12s 12s/step - loss: 0.0278 - categorical_accuracy: 0.9912 - val_loss: 0.1059 - val_categorical_accuracy: 0.9854
# Epoch 559/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0399 - categorical_accuracy: 0.9854 - val_loss: 0.1187 - val_categorical_accuracy: 0.9781
# Epoch 560/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0424 - categorical_accuracy: 0.9844 - val_loss: 0.1344 - val_categorical_accuracy: 0.9751
# Epoch 561/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0520 - categorical_accuracy: 0.9795 - val_loss: 0.0768 - val_categorical_accuracy: 0.9883
# Epoch 562/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0441 - categorical_accuracy: 0.9854 - val_loss: 0.0731 - val_categorical_accuracy: 0.9883
# Epoch 563/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0587 - categorical_accuracy: 0.9834 - val_loss: 0.0747 - val_categorical_accuracy: 0.9868
# Epoch 564/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0321 - categorical_accuracy: 0.9922 - val_loss: 0.1461 - val_categorical_accuracy: 0.9693
# Epoch 565/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0716 - categorical_accuracy: 0.9766 - val_loss: 0.0783 - val_categorical_accuracy: 0.9898
# Epoch 566/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0372 - categorical_accuracy: 0.9864 - val_loss: 0.1121 - val_categorical_accuracy: 0.9825
# Epoch 567/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0620 - categorical_accuracy: 0.9786 - val_loss: 0.1222 - val_categorical_accuracy: 0.9854
# Epoch 568/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0344 - categorical_accuracy: 0.9883 - val_loss: 0.2502 - val_categorical_accuracy: 0.9444
# Epoch 569/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.1144 - categorical_accuracy: 0.9571 - val_loss: 0.0796 - val_categorical_accuracy: 0.9868
# Epoch 570/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.0704 - categorical_accuracy: 0.9815 - val_loss: 0.0962 - val_categorical_accuracy: 0.9766
# Epoch 571/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.1118 - categorical_accuracy: 0.9630 - val_loss: 0.1237 - val_categorical_accuracy: 0.9766
# Epoch 572/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.1058 - categorical_accuracy: 0.9698 - val_loss: 0.1339 - val_categorical_accuracy: 0.9678
# Epoch 573/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.0590 - categorical_accuracy: 0.9805 - val_loss: 0.1827 - val_categorical_accuracy: 0.9591
# Epoch 574/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.0829 - categorical_accuracy: 0.9737 - val_loss: 0.1421 - val_categorical_accuracy: 0.9810
# Epoch 575/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.0589 - categorical_accuracy: 0.9825 - val_loss: 0.1443 - val_categorical_accuracy: 0.9795
# Epoch 576/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.0782 - categorical_accuracy: 0.9727 - val_loss: 0.0989 - val_categorical_accuracy: 0.9854
# Epoch 577/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.0766 - categorical_accuracy: 0.9717 - val_loss: 0.0831 - val_categorical_accuracy: 0.9854
# Epoch 578/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.0775 - categorical_accuracy: 0.9727 - val_loss: 0.1198 - val_categorical_accuracy: 0.9620
# Epoch 579/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.0858 - categorical_accuracy: 0.9669 - val_loss: 0.1317 - val_categorical_accuracy: 0.9766
# Epoch 580/590
# 1/1 [==============================] - 9s 9s/step - loss: 0.0561 - categorical_accuracy: 0.9854 - val_loss: 0.2339 - val_categorical_accuracy: 0.9561
# Epoch 581/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.1376 - categorical_accuracy: 0.9552 - val_loss: 0.0932 - val_categorical_accuracy: 0.9810
# Epoch 582/590
# 1/1 [==============================] - 11s 11s/step - loss: 0.0446 - categorical_accuracy: 0.9854 - val_loss: 0.0872 - val_categorical_accuracy: 0.9810
# Epoch 583/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.1138 - categorical_accuracy: 0.9571 - val_loss: 0.0819 - val_categorical_accuracy: 0.9825
# Epoch 584/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0734 - categorical_accuracy: 0.9815 - val_loss: 0.1131 - val_categorical_accuracy: 0.9708
# Epoch 585/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0621 - categorical_accuracy: 0.9766 - val_loss: 0.0868 - val_categorical_accuracy: 0.9810
# Epoch 586/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0441 - categorical_accuracy: 0.9873 - val_loss: 0.1060 - val_categorical_accuracy: 0.9781
# Epoch 587/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0627 - categorical_accuracy: 0.9825 - val_loss: 0.1011 - val_categorical_accuracy: 0.9781
# Epoch 588/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0940 - categorical_accuracy: 0.9805 - val_loss: 0.0923 - val_categorical_accuracy: 0.9810
# Epoch 589/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0376 - categorical_accuracy: 0.9883 - val_loss: 0.1053 - val_categorical_accuracy: 0.9810
# Epoch 590/590
# 1/1 [==============================] - 10s 10s/step - loss: 0.0577 - categorical_accuracy: 0.9805 - val_loss: 0.1104 - val_categorical_accuracy: 0.9839

# %%
plt.figure(figsize=(9,6))
plt.plot(model_BiLSTM.history.history['categorical_accuracy'], label='Train accuracy')
plt.plot(model_BiLSTM.history.history['val_categorical_accuracy'], label='Validation accuracy')
plt.ylabel('Value')
plt.xlabel('No. epoch')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.plot(model_BiLSTM.history.history['loss'], label='Train loss')
plt.plot(model_BiLSTM.history.history['val_loss'], label='Validation loss')
plt.ylabel('Value')
plt.xlabel('No. epoch')
plt.legend()
plt.show()

# %%
model_BiLSTM.summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_72 (Bidirecti  (None, 30, 256)          1833984
#  onal)
#
#  dropout_96 (Dropout)        (None, 30, 256)           0
#
#  bidirectional_73 (Bidirecti  (None, 30, 512)          1050624
#  onal)
#
#  dropout_97 (Dropout)        (None, 30, 512)           0
#
#  bidirectional_74 (Bidirecti  (None, 256)              656384
#  onal)
#
#  dropout_98 (Dropout)        (None, 256)               0
#
#  dense_72 (Dense)            (None, 64)                16448
#
#  dropout_99 (Dropout)        (None, 64)                0
#
#  dense_73 (Dense)            (None, 32)                2080
#
#  dense_74 (Dense)            (None, 19)                627
#
# =================================================================
# Total params: 3,560,147
# Trainable params: 3,560,147
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_BiLSTM.save('Model/BiLSTM/with_Face/BiLSTM_Model.h5')

# %%
model_BiLSTM = load_model('Model/BiLSTM/with_Face/BiLSTM_Model.h5')

# %% [markdown]
# Test Accuracy Model

# %%
yhat = model_BiLSTM.predict(X_test)
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

model_BiLSTM.evaluate(X_train, y_train)
model_BiLSTM.evaluate(X_test, y_test)
# Out:
# 22/22 [==============================] - 13s 515ms/step
# 33/33 [==============================] - 18s 498ms/step - loss: 0.0167 - categorical_accuracy: 0.9951
# 22/22 [==============================] - 11s 475ms/step - loss: 0.1104 - categorical_accuracy: 0.9839
# [0.11043284088373184, 0.9839181303977966]

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[644,   2],
#         [  1,  37]],
#
#        [[662,   0],
#         [  0,  22]],
#
#        [[648,   0],
#         [  1,  35]],
#
#        [[643,   1],
#         [  0,  40]],
#
#        [[646,   0],
#         [  0,  38]],
#
#        [[646,   3],
#         [  0,  35]],
#
#        [[650,   2],
#         [  0,  32]],
#
#        [[647,   0],
#         [  2,  35]],
#
#        [[646,   0],
#         [  1,  37]],
#
#        [[649,   0],
#         [  1,  34]],
#
#        [[650,   0],
#         [  0,  34]],
#
#        [[650,   0],
#         [  0,  34]],
#
#        [[637,   0],
#         [  2,  45]],
#
#        [[653,   0],
#         [  0,  31]],
#
#        [[641,   0],
#         [  0,  43]],
#
#        [[643,   1],
#         [  0,  40]],
#
#        [[647,   0],
#         [  1,  36]],
#
#        [[656,   2],
#         [  0,  26]],
#
#        [[643,   0],
#         [  2,  39]]], dtype=int64)

# %% [markdown]
# # Test Model in real time

# %%
colors = (0, 204, 102)
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors, -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame
# plt.figure(figsize=(18,18))
# plt.imshow(prob_viz(res, actions, image, colors))

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
confidence = 0.95

cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FPS, 30)
# Set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)

        # Draw landmarks
        draw_styled_landmarks(image, results)

        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]

        if len(sequence) == 30:
            res = model_BiLSTM.predict(np.expand_dims(sequence, axis=0))[0]
            predictions.append(np.argmax(res))

        # 3. Viz logic
            if np.unique(predictions[-10:])[0] == np.argmax(res):
                if res[np.argmax(res)] >= confidence:

                    if len(sentence) > 0:
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 1:
                sentence = sentence[-1:]

        cv2.rectangle(image, (0, 0), (640, 40), (0, 204, 102), -1)
        cv2.putText(image, ' '.join(sentence), (3, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

        # Show to screen
        cv2.imshow('Result', image)

        # Break gracefully
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
        
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
