# %%
import cv2

def record_video(video_path):
    # Define the video codec
    fourcc = cv2.VideoWriter_fourcc(*'XVID')

    # Set up video writer object
    output = cv2.VideoWriter(video_path, fourcc, 30.0, (640, 480))

    # Capture video from the default camera
    cap = cv2.VideoCapture(0)

    while True:
        # Read frame from the camera
        ret, frame = cap.read()

        if ret:
            # Write the frame to the video file
            output.write(frame)

            # Display the resulting frame
            cv2.imshow('Video Recording', frame)

            # Break the loop if 'q' is pressed
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        else:
            break

    # Release the video capture and writer objects
    cap.release()
    output.release()

    # Destroy all OpenCV windows
    cv2.destroyAllWindows()

# Define the path where the video will be saved
video_path = '/GitHub/TSL_Recognition/Collect_videos/You/You7.avi'

# Start recording video
record_video(video_path)

# %%
import cv2

def record_video(video_path):
    # Define the video codec
    fourcc = cv2.VideoWriter_fourcc(*'XVID')

    # Set up video writer object
    output = cv2.VideoWriter(video_path, fourcc, 30.0, (640, 480))

    # Capture video from the default camera
    cap = cv2.VideoCapture(0)

    while True:
        # Read frame from the camera
        ret, frame = cap.read()

        if ret:
            # Write the frame to the video file
            output.write(frame)

            # Display the resulting frame
            cv2.imshow('Video Recording', frame)

            # Break the loop if 'q' is pressed
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        else:
            break

    # Release the video capture and writer objects
    cap.release()
    output.release()

    # Destroy all OpenCV windows
    cv2.destroyAllWindows()

# Define the path where the video will be saved
video_path = '/GitHub/TSL_Recognition/Collect_videos/Sentence/IAm_Love_You/IAm_Love_You10.avi'

# Start recording video
record_video(video_path)

# %%
import cv2

def record_video(video_path):
    # Define the video codec
    fourcc = cv2.VideoWriter_fourcc(*'XVID')

    # Set up video writer object
    output = cv2.VideoWriter(video_path, fourcc, 30.0, (640, 480))

    # Capture video from the default camera
    cap = cv2.VideoCapture(0)

    while True:
        # Read frame from the camera
        ret, frame = cap.read()

        if ret:
            # Write the frame to the video file
            output.write(frame)

            # Display the resulting frame
            cv2.imshow('Video Recording', frame)

            # Break the loop if 'q' is pressed
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        else:
            break

    # Release the video capture and writer objects
    cap.release()
    output.release()

    # Destroy all OpenCV windows
    cv2.destroyAllWindows()

# Define the path where the video will be saved
video_path = '/GitHub/TSL_Recognition/Collect_videos/Combine/Combine5.avi'

# Start recording video
record_video(video_path)
