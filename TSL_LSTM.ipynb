# %% [markdown]
# # Import initial libraries

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import mediapipe as mp
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import multilabel_confusion_matrix

# %% [markdown]
# # Create MediaPipe Function for Detect Body

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)) 
    
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)) 
    
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)) 
    
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2))

# %% [markdown]
# # Test MediaPipe Function with real camera

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
#         print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# # Create Extract Function for Extract Feature

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %% [markdown]
# # Create Datasets

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('DATASET') 

# Actions that we try to detect
actions = np.array(['Beautiful', 'Clever', 'Cute', 'Dislike', 'Fine',
                    'Full', 'Good Luck', 'Hungry', 'Intelligent', 'Like',
                    'Love', 'Regret', 'Sad', 'Sick','Sorry',
                    'Thank You', "That's OK", 'Think of', 'Understand',])

# actions = np.array(['Like', 'Love', 'None'])
# Thirty videos worth of data
no_sequences = 90

# Videos are going to be 30 frames in length
sequence_length = 30

# %%
#for sequence in range(30, no_sequences + 30)
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)
#                 print(results)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 204, 102), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 204, 102), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('Camera', image)
                    cv2.waitKey(1)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,204, 102), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('Camera', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# # Prepare Data for train and test

# %%
label_map = {label:num for num, label in enumerate(actions)}
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
X = np.array(sequences)
y = to_categorical(labels).astype(int)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

# %%
X_train.shape
# Out:
# (1026, 30, 1662)

# %% [markdown]
# # Train model

# %% [markdown]
# Train LSTM Model

# %%
model_LSTM = Sequential([
    LSTM(64, return_sequences=True, activation='relu', input_shape=(30, 1662)),
    Dropout(0.01),
    LSTM(128, return_sequences=True, activation='relu'),
    Dropout(0.01),
    LSTM(64, return_sequences=False, activation='relu'),
    Dropout(0.01),
    Dense(64, activation='relu'),
    Dropout(0.01),
    Dense(32, activation='relu'),
    Dense(actions.shape[0], activation='softmax')])

model_LSTM.compile(optimizer='Adamax', loss='categorical_crossentropy', metrics=[
                   'categorical_accuracy'])
model_LSTM.fit(X_train, y_train, validation_data=(
    X_test, y_test), epochs=120, batch_size=32)
# Out:
# Epoch 1/120
# 33/33 [==============================] - 9s 139ms/step - loss: 2.9440 - categorical_accuracy: 0.0497 - val_loss: 2.9164 - val_categorical_accuracy: 0.0614
# Epoch 2/120
# 33/33 [==============================] - 4s 116ms/step - loss: 2.9127 - categorical_accuracy: 0.0487 - val_loss: 2.8604 - val_categorical_accuracy: 0.0614
# Epoch 3/120
# 33/33 [==============================] - 3s 103ms/step - loss: 2.7481 - categorical_accuracy: 0.1131 - val_loss: 2.6687 - val_categorical_accuracy: 0.1023
# Epoch 4/120
# 33/33 [==============================] - 4s 109ms/step - loss: 2.3348 - categorical_accuracy: 0.1959 - val_loss: 2.2109 - val_categorical_accuracy: 0.2091
# Epoch 5/120
# 33/33 [==============================] - 3s 104ms/step - loss: 2.1491 - categorical_accuracy: 0.2388 - val_loss: 2.2505 - val_categorical_accuracy: 0.2836
# Epoch 6/120
# 33/33 [==============================] - 3s 105ms/step - loss: 2.0241 - categorical_accuracy: 0.2661 - val_loss: 1.9550 - val_categorical_accuracy: 0.2880
# Epoch 7/120
# 33/33 [==============================] - 3s 104ms/step - loss: 1.9397 - categorical_accuracy: 0.3275 - val_loss: 1.7614 - val_categorical_accuracy: 0.3728
# Epoch 8/120
# 33/33 [==============================] - 4s 109ms/step - loss: 1.8068 - categorical_accuracy: 0.3850 - val_loss: 1.7650 - val_categorical_accuracy: 0.3626
# Epoch 9/120
# 33/33 [==============================] - 3s 103ms/step - loss: 1.7016 - categorical_accuracy: 0.4045 - val_loss: 1.5916 - val_categorical_accuracy: 0.4284
# Epoch 10/120
# 33/33 [==============================] - 3s 103ms/step - loss: 1.7238 - categorical_accuracy: 0.3928 - val_loss: 1.4729 - val_categorical_accuracy: 0.4883
# Epoch 11/120
# 33/33 [==============================] - 3s 104ms/step - loss: 1.6453 - categorical_accuracy: 0.4240 - val_loss: 1.4490 - val_categorical_accuracy: 0.4708
# Epoch 12/120
# 33/33 [==============================] - 3s 103ms/step - loss: 1.4576 - categorical_accuracy: 0.4756 - val_loss: 1.3162 - val_categorical_accuracy: 0.5088
# Epoch 13/120
# 33/33 [==============================] - 3s 103ms/step - loss: 1.4486 - categorical_accuracy: 0.4678 - val_loss: 1.4636 - val_categorical_accuracy: 0.4722
# Epoch 14/120
# 33/33 [==============================] - 3s 102ms/step - loss: 1.5857 - categorical_accuracy: 0.4181 - val_loss: 1.3890 - val_categorical_accuracy: 0.4430
# Epoch 15/120
# 33/33 [==============================] - 3s 105ms/step - loss: 1.2889 - categorical_accuracy: 0.4961 - val_loss: 1.4058 - val_categorical_accuracy: 0.4474
# Epoch 16/120
# 33/33 [==============================] - 3s 103ms/step - loss: 1.2623 - categorical_accuracy: 0.5322 - val_loss: 1.2723 - val_categorical_accuracy: 0.5731
# Epoch 17/120
# 33/33 [==============================] - 3s 104ms/step - loss: 1.4450 - categorical_accuracy: 0.4659 - val_loss: 1.0674 - val_categorical_accuracy: 0.5906
# Epoch 18/120
# 33/33 [==============================] - 3s 102ms/step - loss: 1.1063 - categorical_accuracy: 0.5682 - val_loss: 1.8104 - val_categorical_accuracy: 0.3772
# Epoch 19/120
# 33/33 [==============================] - 3s 100ms/step - loss: 1.3309 - categorical_accuracy: 0.5097 - val_loss: 1.0819 - val_categorical_accuracy: 0.5512
# Epoch 20/120
# 33/33 [==============================] - 3s 101ms/step - loss: 1.2397 - categorical_accuracy: 0.5185 - val_loss: 1.1762 - val_categorical_accuracy: 0.5789
# Epoch 21/120
# 33/33 [==============================] - 3s 100ms/step - loss: 1.0894 - categorical_accuracy: 0.5692 - val_loss: 1.5526 - val_categorical_accuracy: 0.4488
# Epoch 22/120
# 33/33 [==============================] - 3s 100ms/step - loss: 1.0868 - categorical_accuracy: 0.5867 - val_loss: 1.1341 - val_categorical_accuracy: 0.5687
# Epoch 23/120
# 33/33 [==============================] - 3s 101ms/step - loss: 1.0216 - categorical_accuracy: 0.6111 - val_loss: 0.8257 - val_categorical_accuracy: 0.7105
# Epoch 24/120
# 33/33 [==============================] - 3s 101ms/step - loss: 0.9130 - categorical_accuracy: 0.6618 - val_loss: 0.9818 - val_categorical_accuracy: 0.6228
# Epoch 25/120
# 33/33 [==============================] - 3s 97ms/step - loss: 0.8442 - categorical_accuracy: 0.6940 - val_loss: 0.9378 - val_categorical_accuracy: 0.6535
# Epoch 26/120
# 33/33 [==============================] - 3s 101ms/step - loss: 0.9612 - categorical_accuracy: 0.6160 - val_loss: 1.0378 - val_categorical_accuracy: 0.5965
# Epoch 27/120
# 33/33 [==============================] - 3s 99ms/step - loss: 0.9252 - categorical_accuracy: 0.6316 - val_loss: 1.5784 - val_categorical_accuracy: 0.3626
# Epoch 28/120
# 33/33 [==============================] - 3s 99ms/step - loss: 1.0157 - categorical_accuracy: 0.6121 - val_loss: 0.7670 - val_categorical_accuracy: 0.7032
# Epoch 29/120
# 33/33 [==============================] - 3s 96ms/step - loss: 0.8071 - categorical_accuracy: 0.6823 - val_loss: 0.9261 - val_categorical_accuracy: 0.6462
# Epoch 30/120
# 33/33 [==============================] - 3s 102ms/step - loss: 0.7823 - categorical_accuracy: 0.6988 - val_loss: 1.4294 - val_categorical_accuracy: 0.5044
# Epoch 31/120
# 33/33 [==============================] - 3s 96ms/step - loss: 1.0408 - categorical_accuracy: 0.5945 - val_loss: 1.1618 - val_categorical_accuracy: 0.5819
# Epoch 32/120
# 33/33 [==============================] - 3s 102ms/step - loss: 0.7321 - categorical_accuracy: 0.7203 - val_loss: 0.7115 - val_categorical_accuracy: 0.7456
# Epoch 33/120
# 33/33 [==============================] - 4s 107ms/step - loss: 0.6616 - categorical_accuracy: 0.7359 - val_loss: 0.7436 - val_categorical_accuracy: 0.7076
# Epoch 34/120
# 33/33 [==============================] - 4s 106ms/step - loss: 0.7920 - categorical_accuracy: 0.7008 - val_loss: 0.6569 - val_categorical_accuracy: 0.7105
# Epoch 35/120
# 33/33 [==============================] - 3s 103ms/step - loss: 0.7251 - categorical_accuracy: 0.7066 - val_loss: 0.5678 - val_categorical_accuracy: 0.8158
# Epoch 36/120
# 33/33 [==============================] - 3s 104ms/step - loss: 0.6734 - categorical_accuracy: 0.7329 - val_loss: 0.8886 - val_categorical_accuracy: 0.6257
# Epoch 37/120
# 33/33 [==============================] - 3s 104ms/step - loss: 0.6651 - categorical_accuracy: 0.7339 - val_loss: 0.7555 - val_categorical_accuracy: 0.6959
# Epoch 38/120
# 33/33 [==============================] - 3s 103ms/step - loss: 0.6044 - categorical_accuracy: 0.7632 - val_loss: 0.6956 - val_categorical_accuracy: 0.7456
# Epoch 39/120
# 33/33 [==============================] - 3s 101ms/step - loss: 0.5962 - categorical_accuracy: 0.7680 - val_loss: 0.6421 - val_categorical_accuracy: 0.7412
# Epoch 40/120
# 33/33 [==============================] - 3s 98ms/step - loss: 0.5570 - categorical_accuracy: 0.7904 - val_loss: 0.6775 - val_categorical_accuracy: 0.7588
# Epoch 41/120
# 33/33 [==============================] - 3s 102ms/step - loss: 0.5831 - categorical_accuracy: 0.7661 - val_loss: 0.5812 - val_categorical_accuracy: 0.7515
# Epoch 42/120
# 33/33 [==============================] - 3s 99ms/step - loss: 0.5803 - categorical_accuracy: 0.7651 - val_loss: 0.9162 - val_categorical_accuracy: 0.5877
# Epoch 43/120
# 33/33 [==============================] - 3s 97ms/step - loss: 0.6088 - categorical_accuracy: 0.7651 - val_loss: 0.6900 - val_categorical_accuracy: 0.7295
# Epoch 44/120
# 33/33 [==============================] - 3s 102ms/step - loss: 0.5902 - categorical_accuracy: 0.7641 - val_loss: 0.5909 - val_categorical_accuracy: 0.7544
# Epoch 45/120
# 33/33 [==============================] - 3s 98ms/step - loss: 0.5249 - categorical_accuracy: 0.8002 - val_loss: 0.4277 - val_categorical_accuracy: 0.8436
# Epoch 46/120
# 33/33 [==============================] - 3s 100ms/step - loss: 0.7755 - categorical_accuracy: 0.6998 - val_loss: 0.6085 - val_categorical_accuracy: 0.7251
# Epoch 47/120
# 33/33 [==============================] - 3s 100ms/step - loss: 0.4581 - categorical_accuracy: 0.8294 - val_loss: 0.5269 - val_categorical_accuracy: 0.7909
# Epoch 48/120
# 33/33 [==============================] - 3s 101ms/step - loss: 0.4911 - categorical_accuracy: 0.8138 - val_loss: 0.4561 - val_categorical_accuracy: 0.8348
# Epoch 49/120
# 33/33 [==============================] - 3s 102ms/step - loss: 0.5738 - categorical_accuracy: 0.7856 - val_loss: 0.5717 - val_categorical_accuracy: 0.7763
# Epoch 50/120
# 33/33 [==============================] - 4s 111ms/step - loss: 0.4973 - categorical_accuracy: 0.7973 - val_loss: 0.5492 - val_categorical_accuracy: 0.7822
# Epoch 51/120
# 33/33 [==============================] - 4s 112ms/step - loss: 0.4669 - categorical_accuracy: 0.8187 - val_loss: 1.0261 - val_categorical_accuracy: 0.7383
# Epoch 52/120
# 33/33 [==============================] - 3s 104ms/step - loss: 0.5968 - categorical_accuracy: 0.7554 - val_loss: 0.6301 - val_categorical_accuracy: 0.7339
# Epoch 53/120
# 33/33 [==============================] - 3s 107ms/step - loss: 0.4620 - categorical_accuracy: 0.8138 - val_loss: 0.4952 - val_categorical_accuracy: 0.8246
# Epoch 54/120
# 33/33 [==============================] - 3s 103ms/step - loss: 0.4189 - categorical_accuracy: 0.8343 - val_loss: 0.4430 - val_categorical_accuracy: 0.8363
# Epoch 55/120
# 33/33 [==============================] - 3s 102ms/step - loss: 0.4339 - categorical_accuracy: 0.8372 - val_loss: 0.7189 - val_categorical_accuracy: 0.7251
# Epoch 56/120
# 33/33 [==============================] - 3s 104ms/step - loss: 0.8502 - categorical_accuracy: 0.7008 - val_loss: 0.6587 - val_categorical_accuracy: 0.7295
# Epoch 57/120
# 33/33 [==============================] - 4s 116ms/step - loss: 0.3892 - categorical_accuracy: 0.8616 - val_loss: 0.3256 - val_categorical_accuracy: 0.8713
# Epoch 58/120
# 33/33 [==============================] - 4s 111ms/step - loss: 0.4773 - categorical_accuracy: 0.8158 - val_loss: 0.5178 - val_categorical_accuracy: 0.7982
# Epoch 59/120
# 33/33 [==============================] - 4s 107ms/step - loss: 0.7310 - categorical_accuracy: 0.7427 - val_loss: 0.4989 - val_categorical_accuracy: 0.8070
# Epoch 60/120
# 33/33 [==============================] - 4s 108ms/step - loss: 0.3559 - categorical_accuracy: 0.8723 - val_loss: 0.3739 - val_categorical_accuracy: 0.8655
# Epoch 61/120
# 33/33 [==============================] - 3s 106ms/step - loss: 0.6055 - categorical_accuracy: 0.7846 - val_loss: 0.4176 - val_categorical_accuracy: 0.8713
# Epoch 62/120
# 33/33 [==============================] - 4s 120ms/step - loss: 0.3093 - categorical_accuracy: 0.8918 - val_loss: 0.5007 - val_categorical_accuracy: 0.8246
# Epoch 63/120
# 33/33 [==============================] - 4s 108ms/step - loss: 0.3370 - categorical_accuracy: 0.8723 - val_loss: 0.3781 - val_categorical_accuracy: 0.8655
# Epoch 64/120
# 33/33 [==============================] - 3s 105ms/step - loss: 0.2670 - categorical_accuracy: 0.8938 - val_loss: 0.3004 - val_categorical_accuracy: 0.9094
# Epoch 65/120
# 33/33 [==============================] - 3s 106ms/step - loss: 0.3384 - categorical_accuracy: 0.8616 - val_loss: 0.8247 - val_categorical_accuracy: 0.7339
# Epoch 66/120
# 33/33 [==============================] - 3s 106ms/step - loss: 0.3805 - categorical_accuracy: 0.8421 - val_loss: 0.3195 - val_categorical_accuracy: 0.8801
# Epoch 67/120
# 33/33 [==============================] - 3s 104ms/step - loss: 0.2921 - categorical_accuracy: 0.8869 - val_loss: 0.3281 - val_categorical_accuracy: 0.9020
# Epoch 68/120
# 33/33 [==============================] - 4s 107ms/step - loss: 0.2264 - categorical_accuracy: 0.9113 - val_loss: 0.2530 - val_categorical_accuracy: 0.9181
# Epoch 69/120
# 33/33 [==============================] - 4s 108ms/step - loss: 0.2271 - categorical_accuracy: 0.9181 - val_loss: 0.2547 - val_categorical_accuracy: 0.9108
# Epoch 70/120
# 33/33 [==============================] - 3s 103ms/step - loss: 0.1868 - categorical_accuracy: 0.9298 - val_loss: 0.2684 - val_categorical_accuracy: 0.9269
# Epoch 71/120
# 33/33 [==============================] - 4s 107ms/step - loss: 0.2260 - categorical_accuracy: 0.9055 - val_loss: 0.4713 - val_categorical_accuracy: 0.8406
# Epoch 72/120
# 33/33 [==============================] - 3s 106ms/step - loss: 0.4034 - categorical_accuracy: 0.8421 - val_loss: 0.2950 - val_categorical_accuracy: 0.8991
# Epoch 73/120
# 33/33 [==============================] - 3s 106ms/step - loss: 0.2107 - categorical_accuracy: 0.9191 - val_loss: 0.2990 - val_categorical_accuracy: 0.9196
# Epoch 74/120
# 33/33 [==============================] - 4s 107ms/step - loss: 0.2728 - categorical_accuracy: 0.8908 - val_loss: 0.8554 - val_categorical_accuracy: 0.6871
# Epoch 75/120
# 33/33 [==============================] - 4s 109ms/step - loss: 0.4766 - categorical_accuracy: 0.8236 - val_loss: 0.6059 - val_categorical_accuracy: 0.7763
# Epoch 76/120
# 33/33 [==============================] - 3s 105ms/step - loss: 0.2926 - categorical_accuracy: 0.8938 - val_loss: 0.3486 - val_categorical_accuracy: 0.8713
# Epoch 77/120
# 33/33 [==============================] - 4s 109ms/step - loss: 0.2796 - categorical_accuracy: 0.8957 - val_loss: 0.2976 - val_categorical_accuracy: 0.9123
# Epoch 78/120
# 33/33 [==============================] - 3s 106ms/step - loss: 0.2514 - categorical_accuracy: 0.9006 - val_loss: 0.3170 - val_categorical_accuracy: 0.8787
# Epoch 79/120
# 33/33 [==============================] - 4s 106ms/step - loss: 0.2880 - categorical_accuracy: 0.8860 - val_loss: 0.7225 - val_categorical_accuracy: 0.7456
# Epoch 80/120
# 33/33 [==============================] - 4s 108ms/step - loss: 0.4766 - categorical_accuracy: 0.8275 - val_loss: 0.4414 - val_categorical_accuracy: 0.8377
# Epoch 81/120
# 33/33 [==============================] - 4s 108ms/step - loss: 0.2943 - categorical_accuracy: 0.8811 - val_loss: 0.6292 - val_categorical_accuracy: 0.8099
# Epoch 82/120
# 33/33 [==============================] - 4s 107ms/step - loss: 0.2497 - categorical_accuracy: 0.9045 - val_loss: 0.3856 - val_categorical_accuracy: 0.8421
# Epoch 83/120
# 33/33 [==============================] - 3s 107ms/step - loss: 0.2463 - categorical_accuracy: 0.9035 - val_loss: 0.4018 - val_categorical_accuracy: 0.8655
# Epoch 84/120
# 33/33 [==============================] - 4s 109ms/step - loss: 0.3102 - categorical_accuracy: 0.8830 - val_loss: 0.2814 - val_categorical_accuracy: 0.9006
# Epoch 85/120
# 33/33 [==============================] - 3s 106ms/step - loss: 0.2464 - categorical_accuracy: 0.9035 - val_loss: 0.3294 - val_categorical_accuracy: 0.9064
# Epoch 86/120
# 33/33 [==============================] - 4s 109ms/step - loss: 0.2651 - categorical_accuracy: 0.9016 - val_loss: 0.5972 - val_categorical_accuracy: 0.7573
# Epoch 87/120
# 33/33 [==============================] - 3s 104ms/step - loss: 0.2288 - categorical_accuracy: 0.9064 - val_loss: 0.5338 - val_categorical_accuracy: 0.8026
# Epoch 88/120
# 33/33 [==============================] - 4s 107ms/step - loss: 0.3888 - categorical_accuracy: 0.8616 - val_loss: 0.9067 - val_categorical_accuracy: 0.6959
# Epoch 89/120
# 33/33 [==============================] - 4s 109ms/step - loss: 0.4838 - categorical_accuracy: 0.8041 - val_loss: 0.3007 - val_categorical_accuracy: 0.8845
# Epoch 90/120
# 33/33 [==============================] - 4s 108ms/step - loss: 0.2186 - categorical_accuracy: 0.9211 - val_loss: 0.3763 - val_categorical_accuracy: 0.8860
# Epoch 91/120
# 33/33 [==============================] - 4s 111ms/step - loss: 0.3059 - categorical_accuracy: 0.8889 - val_loss: 0.2929 - val_categorical_accuracy: 0.9035
# Epoch 92/120
# 33/33 [==============================] - 3s 106ms/step - loss: 0.2214 - categorical_accuracy: 0.9084 - val_loss: 0.5073 - val_categorical_accuracy: 0.8070
# Epoch 93/120
# 33/33 [==============================] - 3s 103ms/step - loss: 0.2171 - categorical_accuracy: 0.9220 - val_loss: 0.3724 - val_categorical_accuracy: 0.8640
# Epoch 94/120
# 33/33 [==============================] - 3s 105ms/step - loss: 0.3444 - categorical_accuracy: 0.8752 - val_loss: 0.4571 - val_categorical_accuracy: 0.8158
# Epoch 95/120
# 33/33 [==============================] - 3s 106ms/step - loss: 0.5559 - categorical_accuracy: 0.8051 - val_loss: 0.2374 - val_categorical_accuracy: 0.9327
# Epoch 96/120
# 33/33 [==============================] - 3s 105ms/step - loss: 0.1728 - categorical_accuracy: 0.9386 - val_loss: 0.2260 - val_categorical_accuracy: 0.9386
# Epoch 97/120
# 33/33 [==============================] - 3s 107ms/step - loss: 0.1631 - categorical_accuracy: 0.9376 - val_loss: 0.2654 - val_categorical_accuracy: 0.9050
# Epoch 98/120
# 33/33 [==============================] - 4s 107ms/step - loss: 0.4709 - categorical_accuracy: 0.8372 - val_loss: 0.2764 - val_categorical_accuracy: 0.8933
# Epoch 99/120
# 33/33 [==============================] - 3s 106ms/step - loss: 0.1638 - categorical_accuracy: 0.9513 - val_loss: 0.4329 - val_categorical_accuracy: 0.8509
# Epoch 100/120
# 33/33 [==============================] - 4s 107ms/step - loss: 0.1843 - categorical_accuracy: 0.9318 - val_loss: 0.1691 - val_categorical_accuracy: 0.9605
# Epoch 101/120
# 33/33 [==============================] - 3s 104ms/step - loss: 0.1233 - categorical_accuracy: 0.9561 - val_loss: 0.6466 - val_categorical_accuracy: 0.7880
# Epoch 102/120
# 33/33 [==============================] - 4s 108ms/step - loss: 0.4593 - categorical_accuracy: 0.8499 - val_loss: 0.2311 - val_categorical_accuracy: 0.9561
# Epoch 103/120
# 33/33 [==============================] - 4s 109ms/step - loss: 0.1573 - categorical_accuracy: 0.9444 - val_loss: 0.2208 - val_categorical_accuracy: 0.9313
# Epoch 104/120
# 33/33 [==============================] - 3s 105ms/step - loss: 0.1258 - categorical_accuracy: 0.9522 - val_loss: 0.3009 - val_categorical_accuracy: 0.9020
# Epoch 105/120
# 33/33 [==============================] - 3s 104ms/step - loss: 0.1285 - categorical_accuracy: 0.9581 - val_loss: 0.1714 - val_categorical_accuracy: 0.9591
# Epoch 106/120
# 33/33 [==============================] - 3s 105ms/step - loss: 0.1282 - categorical_accuracy: 0.9571 - val_loss: 0.2238 - val_categorical_accuracy: 0.9430
# Epoch 107/120
# 33/33 [==============================] - 3s 106ms/step - loss: 0.1084 - categorical_accuracy: 0.9600 - val_loss: 0.2554 - val_categorical_accuracy: 0.9240
# Epoch 108/120
# 33/33 [==============================] - 4s 109ms/step - loss: 0.2483 - categorical_accuracy: 0.9094 - val_loss: 0.2444 - val_categorical_accuracy: 0.9167
# Epoch 109/120
# 33/33 [==============================] - 4s 113ms/step - loss: 0.2176 - categorical_accuracy: 0.9152 - val_loss: 0.2173 - val_categorical_accuracy: 0.9211
# Epoch 110/120
# 33/33 [==============================] - 4s 119ms/step - loss: 0.1973 - categorical_accuracy: 0.9211 - val_loss: 0.1901 - val_categorical_accuracy: 0.9547
# Epoch 111/120
# 33/33 [==============================] - 4s 110ms/step - loss: 0.1566 - categorical_accuracy: 0.9493 - val_loss: 0.4529 - val_categorical_accuracy: 0.8567
# Epoch 112/120
# 33/33 [==============================] - 3s 105ms/step - loss: 0.2401 - categorical_accuracy: 0.9181 - val_loss: 0.3149 - val_categorical_accuracy: 0.9225
# Epoch 113/120
# 33/33 [==============================] - 3s 101ms/step - loss: 0.1400 - categorical_accuracy: 0.9542 - val_loss: 0.6154 - val_categorical_accuracy: 0.8056
# Epoch 114/120
# 33/33 [==============================] - 3s 103ms/step - loss: 0.1927 - categorical_accuracy: 0.9308 - val_loss: 0.2263 - val_categorical_accuracy: 0.9284
# Epoch 115/120
# 33/33 [==============================] - 3s 104ms/step - loss: 0.1407 - categorical_accuracy: 0.9503 - val_loss: 0.1616 - val_categorical_accuracy: 0.9722
# Epoch 116/120
# 33/33 [==============================] - 3s 103ms/step - loss: 0.1660 - categorical_accuracy: 0.9376 - val_loss: 0.8000 - val_categorical_accuracy: 0.8333
# Epoch 117/120
# 33/33 [==============================] - 3s 104ms/step - loss: 0.3555 - categorical_accuracy: 0.8704 - val_loss: 0.3681 - val_categorical_accuracy: 0.8991
# Epoch 118/120
# 33/33 [==============================] - 3s 102ms/step - loss: 0.3546 - categorical_accuracy: 0.8782 - val_loss: 0.9716 - val_categorical_accuracy: 0.7398
# Epoch 119/120
# 33/33 [==============================] - 3s 102ms/step - loss: 0.2792 - categorical_accuracy: 0.9064 - val_loss: 0.2314 - val_categorical_accuracy: 0.9152
# Epoch 120/120
# 33/33 [==============================] - 3s 104ms/step - loss: 0.1426 - categorical_accuracy: 0.9444 - val_loss: 0.1554 - val_categorical_accuracy: 0.9664

# %%
plt.figure(figsize=(9,6))
plt.plot(model_LSTM.history.history['categorical_accuracy'], label='Train accuracy')
plt.plot(model_LSTM.history.history['val_categorical_accuracy'], label='Validation accuracy')
plt.ylabel('Value')
plt.xlabel('No. epoch')
plt.legend()
plt.show()
# plt.savefig('Model/LSTM/plt_LSTM.png')

# %%
plt.figure(figsize=(9,6))
plt.plot(model_LSTM.history.history['loss'], label='Train loss')
plt.plot(model_LSTM.history.history['val_loss'], label='Validation loss')
plt.ylabel('Value')
plt.xlabel('No. epoch')
plt.legend()
plt.show()

# %%
model_LSTM.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 30, 64)            442112
#
#  dropout_4 (Dropout)         (None, 30, 64)            0
#
#  lstm_4 (LSTM)               (None, 30, 128)           98816
#
#  dropout_5 (Dropout)         (None, 30, 128)           0
#
#  lstm_5 (LSTM)               (None, 64)                49408
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 19)                627
#
# =================================================================
# Total params: 597,203
# Trainable params: 597,203
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_LSTM.save('Model/LSTM/LSTM_Model.h5')

# %%
model_LSTM = load_model('Model/LSTM/LSTM_Model.h5')

# %% [markdown]
# Test Accuracy Model

# %%
yhat = model_LSTM.predict(X_test)
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

model_LSTM.evaluate(X_train, y_train)
model_LSTM.evaluate(X_test, y_test)
# accuracy_score(ytrue, yhat)
# Out:
# 22/22 [==============================] - 1s 28ms/step
# 33/33 [==============================] - 1s 28ms/step - loss: 0.0626 - categorical_accuracy: 0.9854
# 22/22 [==============================] - 1s 30ms/step - loss: 0.1554 - categorical_accuracy: 0.9664
# [0.15540391206741333, 0.9663742780685425]

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[647,   2],
#         [  0,  35]],
#
#        [[647,   2],
#         [  1,  34]],
#
#        [[649,   0],
#         [  2,  33]],
#
#        [[649,   5],
#         [  1,  29]],
#
#        [[647,   0],
#         [  0,  37]],
#
#        [[637,   2],
#         [  0,  45]],
#
#        [[646,   3],
#         [  3,  32]],
#
#        [[649,   0],
#         [  1,  34]],
#
#        [[644,   0],
#         [  1,  39]],
#
#        [[642,   0],
#         [  6,  36]],
#
#        [[655,   0],
#         [  1,  28]],
#
#        [[643,   1],
#         [  0,  40]],
#
#        [[653,   0],
#         [  1,  30]],
#
#        [[648,   2],
#         [  0,  34]],
#
#        [[646,   5],
#         [  0,  33]],
#
#        [[650,   0],
#         [  2,  32]],
#
#        [[645,   0],
#         [  1,  38]],
#
#        [[643,   1],
#         [  1,  39]],
#
#        [[649,   0],
#         [  2,  33]]], dtype=int64)

# %% [markdown]
# # Test Model in real time

# %%
colors = (0, 204, 102)
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors, -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame
# plt.figure(figsize=(18,18))
# plt.imshow(prob_viz(res, actions, image, colors))

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
confidence = 0.99

cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FPS, 30)
# Set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)

        # Draw landmarks
        draw_styled_landmarks(image, results)

        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]

        if len(sequence) == 30:
            res = model_LSTM.predict(np.expand_dims(sequence, axis=0))[0]
            predictions.append(np.argmax(res))

        # 3. Viz logic
            if np.unique(predictions[-10:])[0] == np.argmax(res):
                if res[np.argmax(res)] >= confidence:

                    if len(sentence) > 0:
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 1:
                sentence = sentence[-1:]

        cv2.rectangle(image, (0, 0), (640, 40), (0, 204, 102), -1)
        cv2.putText(image, ' '.join(sentence), (3, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

        # Show to screen
        cv2.imshow('Result', image)

        # Break gracefully
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
        
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
